# %% [markdown]
# **Deep Learning from Scratch**

# %% [markdown]
# **Linear Model**

# %%
import model
import layers
import deep_learning_runner

# Use Original Model
runner = deep_learning_runner.DeepLearningRunner()
runner.run()
# Out:
# ['.idea', '.venv', 'deep_learning_runner.py', 'layers.py', 'main.py', 'math_utility.py', 'model.py', 'multiply_dataset.csv', 'Project#1DeepLearning.ipynb', 'README.txt', '__pycache__']
# Inputs shape: (25, 2)
# Targets shape: (25, 1)
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.951339 | Test RMSE: 0.910200
# Epoch   50 | Train RMSE: 0.122962 | Test RMSE: 0.152619
# Epoch  100 | Train RMSE: 0.149734 | Test RMSE: 0.138820
# Epoch  150 | Train RMSE: 0.141518 | Test RMSE: 0.183281
# Epoch  200 | Train RMSE: 0.128507 | Test RMSE: 0.131257
# Epoch  250 | Train RMSE: 0.131140 | Test RMSE: 0.133056
# Epoch  300 | Train RMSE: 0.149778 | Test RMSE: 0.199631
# Epoch  350 | Train RMSE: 0.130831 | Test RMSE: 0.166724
# Epoch  400 | Train RMSE: 0.121868 | Test RMSE: 0.145851
# Epoch  450 | Train RMSE: 0.122248 | Test RMSE: 0.149255
# Epoch  500 | Train RMSE: 0.121915 | Test RMSE: 0.148046
# Quick tests:
# x=0.20, y=0.70 -> pred=0.177326, actual=0.140000
# x=0.50, y=0.50 -> pred=0.228635, actual=0.250000
# x=1.00, y=0.30 -> pred=0.384885, actual=0.300000
# x=0.30, y=0.90 -> pred=0.335900, actual=0.270000
# x=1.00, y=0.45 -> pred=0.464463, actual=0.450000

# %% [markdown]
# **ReLU Model**

# %%
model_ReLU = model.Model([
    layers.ReLU(2, 2, seed=1),
    layers.ReLU(2, 2, seed=2),
    layers.ReLU(2, 1, seed=3),
])

runner.replace_model(model_ReLU," ReLU")
runner.run()
# Out:
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.206694 | Test RMSE: 0.178864
# Epoch   50 | Train RMSE: 0.060318 | Test RMSE: 0.029763
# Epoch  100 | Train RMSE: 0.049496 | Test RMSE: 0.037837
# Epoch  150 | Train RMSE: 0.043415 | Test RMSE: 0.048610
# Epoch  200 | Train RMSE: 0.042456 | Test RMSE: 0.054685
# Epoch  250 | Train RMSE: 0.038321 | Test RMSE: 0.063507
# Epoch  300 | Train RMSE: 0.034033 | Test RMSE: 0.068835
# Epoch  350 | Train RMSE: 0.032914 | Test RMSE: 0.067913
# Epoch  400 | Train RMSE: 0.031255 | Test RMSE: 0.061627
# Epoch  450 | Train RMSE: 0.030723 | Test RMSE: 0.062093
# Epoch  500 | Train RMSE: 0.033709 | Test RMSE: 0.070869
# Quick tests:
# x=0.20, y=0.70 -> pred=0.066538, actual=0.140000
# x=0.50, y=0.50 -> pred=0.261557, actual=0.250000
# x=1.00, y=0.30 -> pred=0.267370, actual=0.300000
# x=0.30, y=0.90 -> pred=0.244822, actual=0.270000
# x=1.00, y=0.45 -> pred=0.431354, actual=0.450000

# %% [markdown]
# **Sigmoid Model**

# %%
model_Sigmoid = model.Model([
    layers.Sigmoid(2, 2, seed=1),
    layers.Sigmoid(2, 2, seed=2),
    layers.Sigmoid(2, 1, seed=3),
])

runner.replace_model(model_Sigmoid," Sigmoid")
runner.run()
# Out:
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.409633 | Test RMSE: 0.393882
# Epoch   50 | Train RMSE: 0.295379 | Test RMSE: 0.270029
# Epoch  100 | Train RMSE: 0.287397 | Test RMSE: 0.260692
# Epoch  150 | Train RMSE: 0.286165 | Test RMSE: 0.259171
# Epoch  200 | Train RMSE: 0.285720 | Test RMSE: 0.258664
# Epoch  250 | Train RMSE: 0.285306 | Test RMSE: 0.258209
# Epoch  300 | Train RMSE: 0.284906 | Test RMSE: 0.257792
# Epoch  350 | Train RMSE: 0.284511 | Test RMSE: 0.257342
# Epoch  400 | Train RMSE: 0.284119 | Test RMSE: 0.256922
# Epoch  450 | Train RMSE: 0.283729 | Test RMSE: 0.256499
# Epoch  500 | Train RMSE: 0.283354 | Test RMSE: 0.256109
# Quick tests:
# x=0.20, y=0.70 -> pred=0.244417, actual=0.140000
# x=0.50, y=0.50 -> pred=0.255000, actual=0.250000
# x=1.00, y=0.30 -> pred=0.269875, actual=0.300000
# x=0.30, y=0.90 -> pred=0.243482, actual=0.270000
# x=1.00, y=0.45 -> pred=0.267562, actual=0.450000

# %% [markdown]
# **Tanh Model**

# %%
model_Tanh = model.Model([
    layers.Tanh(2, 2, seed=1),
    layers.Tanh(2, 2, seed=2),
    layers.Tanh(2, 1, seed=3),
])

runner.replace_model(model_Tanh," TanH")
runner.run()
# Out:
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.527477 | Test RMSE: 0.546866
# Epoch   50 | Train RMSE: 0.121987 | Test RMSE: 0.158914
# Epoch  100 | Train RMSE: 0.120397 | Test RMSE: 0.146900
# Epoch  150 | Train RMSE: 0.099542 | Test RMSE: 0.143285
# Epoch  200 | Train RMSE: 0.093429 | Test RMSE: 0.128708
# Epoch  250 | Train RMSE: 0.089320 | Test RMSE: 0.124702
# Epoch  300 | Train RMSE: 0.088200 | Test RMSE: 0.125096
# Epoch  350 | Train RMSE: 0.088026 | Test RMSE: 0.120292
# Epoch  400 | Train RMSE: 0.092169 | Test RMSE: 0.124527
# Epoch  450 | Train RMSE: 0.085667 | Test RMSE: 0.109598
# Epoch  500 | Train RMSE: 0.083771 | Test RMSE: 0.111528
# Quick tests:
# x=0.20, y=0.70 -> pred=0.185486, actual=0.140000
# x=0.50, y=0.50 -> pred=0.357842, actual=0.250000
# x=1.00, y=0.30 -> pred=0.257275, actual=0.300000
# x=0.30, y=0.90 -> pred=0.292523, actual=0.270000
# x=1.00, y=0.45 -> pred=0.390076, actual=0.450000

# %% [markdown]
# **LeakyReLU Model**

# %%
model_LeakyReLU = model.Model([
    layers.LeakyReLU(2, 2, seed=1),
    layers.LeakyReLU(2, 2, seed=2),
    layers.LeakyReLU(2, 1, seed=3),
])

runner.replace_model(model_LeakyReLU," Leaky ReLU")
runner.run()
# Out:
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.205267 | Test RMSE: 0.176273
# Epoch   50 | Train RMSE: 0.057817 | Test RMSE: 0.017024
# Epoch  100 | Train RMSE: 0.048885 | Test RMSE: 0.038024
# Epoch  150 | Train RMSE: 0.042899 | Test RMSE: 0.052835
# Epoch  200 | Train RMSE: 0.040611 | Test RMSE: 0.061376
# Epoch  250 | Train RMSE: 0.036834 | Test RMSE: 0.065988
# Epoch  300 | Train RMSE: 0.033398 | Test RMSE: 0.068002
# Epoch  350 | Train RMSE: 0.032555 | Test RMSE: 0.067658
# Epoch  400 | Train RMSE: 0.031057 | Test RMSE: 0.061718
# Epoch  450 | Train RMSE: 0.030633 | Test RMSE: 0.062337
# Epoch  500 | Train RMSE: 0.033731 | Test RMSE: 0.070874
# Quick tests:
# x=0.20, y=0.70 -> pred=0.066510, actual=0.140000
# x=0.50, y=0.50 -> pred=0.261759, actual=0.250000
# x=1.00, y=0.30 -> pred=0.268035, actual=0.300000
# x=0.30, y=0.90 -> pred=0.244669, actual=0.270000
# x=1.00, y=0.45 -> pred=0.431008, actual=0.450000

# %% [markdown]
# **Piecewise Model**

# %%
model_Piecewise = model.Model([
    layers.Piecewise(2, 2, seed=1),
    layers.Piecewise(2, 2, seed=2),
    layers.Piecewise(2, 1, seed=3),
])

runner.replace_model(model_Piecewise," Piecewise")
runner.run()
# Out:
# Running Deep Learning Runner
# Epoch    1 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch   50 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  100 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  150 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  200 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  250 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  300 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  350 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  400 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  450 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Epoch  500 | Train RMSE: 0.378628 | Test RMSE: 0.360122
# Quick tests:
# x=0.20, y=0.70 -> pred=0.000000, actual=0.140000
# x=0.50, y=0.50 -> pred=0.000000, actual=0.250000
# x=1.00, y=0.30 -> pred=0.000000, actual=0.300000
# x=0.30, y=0.90 -> pred=0.000000, actual=0.270000
# x=1.00, y=0.45 -> pred=0.000000, actual=0.450000
